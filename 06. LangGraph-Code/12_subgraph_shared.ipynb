# %%
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
class ParentState(TypedDict):

    question: str
    answer_eng: str
    answer_hin: str

# %%
parent_llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.7
)

subgraph_llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.7
)

# %%
def translate_text(state: ParentState):

    prompt = f"""
Translate the following text to Hindi.
Keep it natural and clear. Do not add extra content.

Text:
{state["answer_eng"]}
""".strip()
    
    translated_text = subgraph_llm.invoke(prompt).content

    return {'answer_hin': translated_text}

# %%
subgraph_builder = StateGraph(ParentState)

subgraph_builder.add_node('translate_text', translate_text)

subgraph_builder.add_edge(START, 'translate_text')
subgraph_builder.add_edge('translate_text', END)

subgraph = subgraph_builder.compile()

# %%
def generate_answer(state: ParentState):

    answer = parent_llm.invoke(f"You are a helpful assistant. Answer clearly.\n\nQuestion: {state['question']}").content
    return {'answer_eng': answer}

# %%
parent_builder = StateGraph(ParentState)

parent_builder.add_node("answer", generate_answer)
parent_builder.add_node("translate", subgraph)

parent_builder.add_edge(START, 'answer')
parent_builder.add_edge('answer', 'translate')
parent_builder.add_edge('translate', END)

# %%
graph = parent_builder.compile()

graph

# %%
graph.invoke({'question': 'What is quantum physics'})
# Out:
# {'question': 'What is quantum physics',
#  'answer_eng': 'Quantum physics (also known as quantum mechanics or quantum theory) is a fundamental branch of physics that describes the **behavior of matter and energy at the smallest scales**: atoms, subatomic particles (like electrons, protons, and neutrons), and photons (particles of light).\n\nIt\'s fundamentally different from classical physics (which describes the world we experience every day) because the rules that govern the very small are counter-intuitive and often defy our everyday logic.\n\nHere are the core ideas that define quantum physics:\n\n1.  **Quantization:** Energy, momentum, angular momentum, and other properties of particles are not continuous (like a ramp) but come in discrete, indivisible packets called "quanta" (like steps on a staircase). For example, light isn\'t just a wave; it\'s also made of individual energy packets called photons.\n\n2.  **Wave-Particle Duality:** Particles, like electrons, can behave like waves (spreading out and interfering with themselves), and waves, like light, can behave like particles. They exhibit characteristics of both, depending on how they are observed.\n\n3.  **Superposition:** Before being measured, a quantum particle can exist in multiple states *simultaneously*. For example, an electron can be spinning both "up" and "down" at the same time. It\'s only when we measure it that it "collapses" into one definite state. (This is famously illustrated by Schrödinger\'s Cat thought experiment).\n\n4.  **Entanglement:** Two or more quantum particles can become linked in such a way that they share the same fate, no matter how far apart they are. Measuring the state of one instantly influences the state of the other, even if they are light-years apart. This is what Einstein famously called "spooky action at a distance."\n\n5.  **Uncertainty Principle (Heisenberg):** You cannot precisely know certain pairs of properties of a particle at the same time. For example, the more accurately you know a particle\'s position, the less accurately you can know its momentum, and vice-versa. The act of measuring one property inevitably disturbs the other.\n\n6.  **Probabilistic Nature:** Unlike classical physics, which can often predict exact outcomes, quantum physics often describes the probability of different outcomes. We can\'t always say *what* will happen, but we can say how likely it is.\n\n**Why is it important?**\n\nDespite its "weirdness," quantum physics is incredibly successful and forms the bedrock of our understanding of the universe at its most fundamental level. It explains:\n\n*   How atoms hold together.\n*   The nature of chemical bonds.\n*   How stars burn.\n*   The properties of materials.\n\nIt\'s also the basis for much of modern technology, including:\n\n*   **Lasers** (used in everything from CD/DVD players to fiber optics and medical surgery)\n*   **Transistors** (the building blocks of all modern computers and electronics)\n*   **MRI scanners**\n*   **LEDs**\n*   **Solar cells**\n*   **Atomic clocks**\n*   **Quantum computing** and **quantum cryptography** (emerging technologies)\n\nIn essence, quantum physics is the rulebook for the very small, revealing a reality that is far stranger and more fascinating than our everyday experience suggests, yet it underpins everything we see and interact with.',
#  'answer_hin': 'क्वांटम भौतिकी (जिसे क्वांटम यांत्रिकी या क्वांटम सिद्धांत के नाम से भी जाना जाता है) भौतिकी की एक मूलभूत शाखा है जो सबसे छोटे पैमाने पर पदार्थ और ऊर्जा के व्यवहार का वर्णन करती है: जैसे परमाणु, उप-परमाणु कण (इलेक्ट्रॉन, प्रोटॉन और न्यूट्रॉन), और फोटॉन (प्रकाश के कण)।\n\nयह शास्त्रीय भौतिकी (जो उस दुनिया का वर्णन करती है जिसका हम हर दिन अनुभव करते हैं) से मौलिक रूप से भिन्न है, क्योंकि बहुत छोटे कणों को नियंत्रित करने वाले नियम सहज ज्ञान के विपरीत होते हैं और अक्सर हमारे रोज़मर्रा के तर्क को धता बताते हैं।\n\nयहाँ वे मुख्य विचार दिए गए हैं जो क्वांटम भौतिकी को परिभाषित करते हैं:\n\n1.  **क्वांटाइजेशन (Quantization):** ऊर्जा, संवेग, कोणीय संवेग और कणों के अन्य गुण सतत (एक ढलान की तरह) नहीं होते, बल्कि "क्वांटा" नामक असतत, अविभाज्य पैकेटों में आते हैं (एक सीढ़ी के चरणों की तरह)। उदाहरण के लिए, प्रकाश केवल एक तरंग नहीं है; यह फोटॉन नामक व्यक्तिगत ऊर्जा पैकेटों से भी बना है।\n\n2.  **तरंग-कण द्वैतता (Wave-Particle Duality):** इलेक्ट्रॉन जैसे कण तरंगों की तरह (फैलते हुए और आपस में हस्तक्षेप करते हुए) व्यवहार कर सकते हैं, और प्रकाश जैसी तरंगें कणों की तरह व्यवहार कर सकती हैं। वे दोनों की विशेषताएँ प्रदर्शित करते हैं, यह इस बात पर निर्भर करता है कि उन्हें कैसे देखा जाता है।\n\n3.  **सुपरपोज़िशन (Superposition):** मापे जाने से पहले, एक क्वांटम कण एक साथ कई अवस्थाओं में मौजूद हो सकता है। उदाहरण के लिए, एक इलेक्ट्रॉन एक ही समय में "ऊपर" और "नीचे" दोनों दिशाओं में घूम सकता है। यह तभी होता है जब हम इसे मापते हैं कि यह एक निश्चित अवस्था में "ढह" जाता है। (इसे श्रोडिंगर की बिल्ली के विचार प्रयोग द्वारा प्रसिद्ध रूप से दर्शाया गया है)।\n\n4.  **एंटैंगलमेंट (Entanglement):** दो या दो से अधिक क्वांटम कण इस तरह से जुड़ सकते हैं कि वे एक ही भाग्य साझा करते हैं, चाहे वे कितनी भी दूर क्यों न हों। एक की अवस्था को मापने से दूसरे की अवस्था तुरंत प्रभावित होती है, भले ही वे प्रकाश-वर्ष दूर हों। इसे ही आइंस्टीन ने प्रसिद्ध रूप से "दूरी पर रहस्यमय क्रिया" कहा था।\n\n5.  **अनिश्चितता सिद्धांत (हाइजेनबर्ग) (Uncertainty Principle - Heisenberg):** आप एक ही समय में एक कण के कुछ गुणों के जोड़े को सटीक रूप से नहीं जान सकते। उदाहरण के लिए, आप एक कण की स्थिति को जितनी अधिक सटीकता से जानेंगे, उतनी ही कम सटीकता से आप उसके संवेग को जान पाएंगे, और इसके विपरीत भी। एक गुण को मापने का कार्य अनिवार्य रूप से दूसरे को बाधित करता है।\n\n6.  **संभाव्य प्रकृति (Probabilistic Nature):** शास्त्रीय भौतिकी के विपरीत, जो अक्सर सटीक परिणामों की भविष्यवाणी कर सकती है, क्वांटम भौतिकी अक्सर विभिन्न परिणामों की संभावना का वर्णन करती है। हम हमेशा यह नहीं कह सकते कि *क्या* होगा, लेकिन हम यह कह सकते हैं कि इसकी कितनी संभावना है।\n\n**यह महत्वपूर्ण क्यों है?**\n\nअपनी "अजीबोगरीब" प्रकृति के बावजूद, क्वांटम भौतिकी अविश्वसनीय रूप से सफल है और ब्रह्मांड की हमारी समझ का सबसे मूलभूत आधार बनती है। यह समझाती है:\n\n*   परमाणु कैसे जुड़े रहते हैं।\n*   रासायनिक बंधों की प्रकृति।\n*   तारे कैसे जलते हैं।\n*   सामग्रियों के गुण।\n\nयह आधुनिक तकनीक के बहुत से हिस्सों का आधार भी है, जिनमें शामिल हैं:\n\n*   **लेज़र** (CD/DVD प्लेयर से लेकर फाइबर ऑप्टिक्स और चिकित्सा सर्जरी तक हर चीज़ में उपयोग किए जाते हैं)\n*   **ट्रांजिस्टर** (सभी आधुनिक कंप्यूटरों और इलेक्ट्रॉनिक्स के बिल्डिंग ब्लॉक्स)\n*   **एमआरआई स्कैनर**\n*   **एलईडी**\n*   **सौर सेल**\n*   **परमाणु घड़ियाँ**\n*   **क्वांटम कंप्यूटिंग** और **क्वांटम क्रिप्टोग्राफी** (उभरती हुई प्रौद्योगिकियाँ)\n\nसंक्षेप में, क्वांटम भौतिकी बहुत छोटे कणों के लिए नियम-पुस्तिका है, जो एक ऐसी वास्तविकता को उजागर करती है जो हमारे रोज़मर्रा के अनुभव से कहीं अधिक अजीब और आकर्षक है, फिर भी यह उन सभी चीज़ों का आधार है जिन्हें हम देखते और जिनके साथ बातचीत करते हैं।'}
