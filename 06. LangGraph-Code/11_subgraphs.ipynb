# %%
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
class SubState(TypedDict):

    input_text: str
    translated_text: str

# %%
subgraph_llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.7
)

# %%
def translate_text(state: SubState):

    prompt = f"""
Translate the following text to Hindi.
Keep it natural and clear. Do not add extra content.

Text:
{state["input_text"]}
""".strip()
    
    translated_text = subgraph_llm.invoke(prompt).content

    return {'translated_text': translated_text}

# %%
subgraph_builder = StateGraph(SubState)

subgraph_builder.add_node('translate_text', translate_text)

subgraph_builder.add_edge(START, 'translate_text')
subgraph_builder.add_edge('translate_text', END)

subgraph = subgraph_builder.compile()

# %%
class ParentState(TypedDict):

    question: str
    answer_eng: str
    answer_hin: str

# %%
parent_llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.7
)

# %%
def generate_answer(state: ParentState):

    answer = parent_llm.invoke(f"You are a helpful assistant. Answer clearly.\n\nQuestion: {state['question']}").content
    return {'answer_eng': answer}

# %%
def translate_answer(state: ParentState):

    # call the subgraph
    result = subgraph.invoke({'input_text': state['answer_eng']})

    return {'answer_hin': result['translated_text']}

# %%
parent_builder = StateGraph(ParentState)

parent_builder.add_node("answer", generate_answer)
parent_builder.add_node("translate", translate_answer)

parent_builder.add_edge(START, 'answer')
parent_builder.add_edge('answer', 'translate')
parent_builder.add_edge('translate', END)

# %%
graph = parent_builder.compile()

graph

# %%
graph.invoke({'question': 'What is quantum physics'})
# Out:
# {'question': 'What is quantum physics',
#  'answer_eng': 'Quantum physics, also known as quantum mechanics, is a fundamental branch of physics that describes the behavior of matter and energy at the smallest scales: the atomic and subatomic levels.\n\n**In essence, it\'s the science of the very, very small.**\n\nHere\'s a breakdown of what makes it so distinct and fascinating:\n\n1.  **Classical Physics Breaks Down:** Our everyday experience and the rules of "classical physics" (like Isaac Newton\'s laws) work perfectly for large objects. But when you zoom in to the size of atoms and their components (electrons, protons, neutrons, photons), those rules no longer apply. Quantum physics provides a new set of rules for this tiny realm.\n\n2.  **Quantization (The "Quantum" Part):**\n    *   The word "quantum" means a discrete, indivisible unit or packet.\n    *   In quantum physics, many physical properties (like energy, momentum, and angular momentum) aren\'t continuous; they exist only in specific, discrete values, like steps on a staircase rather than a smooth ramp.\n    *   For example, electrons in an atom can only occupy specific energy levels, not just any energy level in between. When they jump between these levels, they absorb or emit a "quantum" of energy (a photon).\n\n3.  **Wave-Particle Duality:**\n    *   One of the most mind-bending concepts: tiny particles like electrons and photons don\'t behave *purely* as either particles (tiny balls) or waves (like water waves).\n    *   They exhibit properties of both! Light, for instance, can act as a wave (explaining diffraction and interference) but also as a stream of particles called photons (explaining the photoelectric effect).\n    *   Similarly, electrons can act as particles (having mass and charge) but also display wave-like behavior.\n\n4.  **Uncertainty Principle (Heisenberg):**\n    *   This principle states that you cannot simultaneously know with perfect precision certain pairs of properties of a particle.\n    *   For example, the more precisely you know an electron\'s position, the less precisely you can know its momentum (and vice-versa).\n    *   It\'s not about limitations of our measuring instruments; it\'s a fundamental property of nature at the quantum level.\n\n5.  **Superposition:**\n    *   Before being measured, a quantum particle can exist in multiple possible states *at the same time*.\n    *   Imagine a coin spinning in the air: it\'s neither heads nor tails until it lands. A quantum particle is like that spinning coin, existing in a superposition of "heads" and "tails" until an observation "collapses" it into one definite state.\n    *   (Schrödinger\'s cat is a famous thought experiment illustrating this, though it\'s an analogy for the quantum world, not a literal description of macroscopic cats).\n\n6.  **Entanglement:**\n    *   When two or more quantum particles become "entangled," they become linked in such a way that they share the same fate, no matter how far apart they are.\n    *   Measuring a property of one entangled particle instantaneously influences the property of the other, even if they are light-years apart. Albert Einstein famously called this "spooky action at a distance."\n\n7.  **Probability, Not Determinism:**\n    *   Unlike classical physics, which can often predict exact outcomes, quantum physics often deals in probabilities. It tells you the *likelihood* of finding a particle in a certain state or position, rather than its exact trajectory.\n\n**Why is it important?**\n\nQuantum physics isn\'t just theoretical weirdness; it\'s incredibly accurate and forms the basis for much of modern technology and our understanding of the universe:\n\n*   **Lasers:** Used in everything from DVD players to fiber optics and medical surgery.\n*   **Transistors:** The fundamental building blocks of all modern electronics (computers, smartphones).\n*   **MRI Scanners:** Medical imaging that uses quantum properties of atomic nuclei.\n*   **LEDs:** Efficient light sources.\n*   **A ...
#  'answer_hin': 'यहाँ दिए गए पाठ का हिंदी अनुवाद है:\n\nक्वांटम भौतिकी, जिसे क्वांटम यांत्रिकी के नाम से भी जाना जाता है, भौतिकी की एक मूलभूत शाखा है जो सबसे छोटे पैमाने पर पदार्थ और ऊर्जा के व्यवहार का वर्णन करती है: परमाणु और उप-परमाणु स्तरों पर।\n\n**संक्षेप में, यह अति-सूक्ष्म का विज्ञान है।**\n\nयहाँ एक विवरण दिया गया है कि क्या इसे इतना विशिष्ट और आकर्षक बनाता है:\n\n1.  **शास्त्रीय भौतिकी का विफल होना:** हमारे रोज़मर्रा के अनुभव और "शास्त्रीय भौतिकी" (जैसे आइजैक न्यूटन के नियम) के नियम बड़ी वस्तुओं के लिए पूरी तरह से काम करते हैं। लेकिन जब आप परमाणुओं और उनके घटकों (इलेक्ट्रॉन, प्रोटॉन, न्यूट्रॉन, फोटॉन) के आकार तक ज़ूम करते हैं, तो वे नियम लागू नहीं होते। क्वांटम भौतिकी इस सूक्ष्म क्षेत्र के लिए नियमों का एक नया सेट प्रदान करती है।\n\n2.  **क्वांटमीकरण ("क्वांटम" भाग):**\n    *   "क्वांटम" शब्द का अर्थ है एक असतत (discrete), अविभाज्य इकाई या पैकेट।\n    *   क्वांटम भौतिकी में, कई भौतिक गुण (जैसे ऊर्जा, संवेग और कोणीय संवेग) निरंतर नहीं होते हैं; वे केवल विशिष्ट, असतत मानों में मौजूद होते हैं, जैसे एक चिकनी ढलान के बजाय सीढ़ियों के कदम।\n    *   उदाहरण के लिए, एक परमाणु में इलेक्ट्रॉन केवल विशिष्ट ऊर्जा स्तरों पर ही रह सकते हैं, न कि बीच के किसी भी ऊर्जा स्तर पर। जब वे इन स्तरों के बीच कूदते हैं, तो वे ऊर्जा का एक "क्वांटम" (एक फोटॉन) अवशोषित या उत्सर्जित करते हैं।\n\n3.  **तरंग-कण द्वैतता:**\n    *   सबसे मन को चकरा देने वाली अवधारणाओं में से एक: इलेक्ट्रॉन और फोटॉन जैसे छोटे कण *पूरी तरह से* न तो कणों (छोटे गोले) की तरह व्यवहार करते हैं और न ही तरंगों (जैसे पानी की तरंगें) की तरह।\n    *   वे दोनों के गुण प्रदर्शित करते हैं! उदाहरण के लिए, प्रकाश एक तरंग के रूप में कार्य कर सकता है (विवर्तन और व्यतिकरण की व्याख्या करता है) लेकिन फोटॉन नामक कणों की एक धारा के रूप में भी (प्रकाशविद्युत प्रभाव की व्याख्या करता है)।\n    *   इसी तरह, इलेक्ट्रॉन कणों के रूप में (द्रव्यमान और आवेश वाले) कार्य कर सकते हैं लेकिन तरंग-जैसे व्यवहार भी प्रदर्शित करते हैं।\n\n4.  **अनिश्चितता सिद्धांत (हाइजेनबर्ग):**\n    *   यह सिद्धांत कहता है कि आप एक कण के कुछ गुणों की जोड़ियों को एक साथ पूर्ण सटीकता के साथ नहीं जान सकते।\n    *   उदाहरण के लिए, आप एक इलेक्ट्रॉन की स्थिति जितनी अधिक सटीकता से जानते हैं, उतनी ही कम सटीकता से आप उसके संवेग को जान सकते हैं (और इसके विपरीत)।\n    *   यह हमारे मापने वाले उपकरणों की सीमाओं के बारे में नहीं है; यह क्वांटम स्तर पर प्रकृति का एक मौलिक गुण है।\n\n5.  **अध्यारोपण:**\n    *   मापा जाने से पहले, एक क्वांटम कण *एक ही समय में* कई संभावित अवस्थाओं में मौजूद हो सकता है।\n    *   हवा में घूमते हुए एक सिक्के की कल्पना करें: जब तक वह गिरता नहीं, तब तक वह न तो चित्त होता है और न ही पट। एक क्वांटम कण उस घूमते हुए सिक्के की तरह है, जो "चित्त" और "पट" के अध्यारोपण में मौजूद होता है जब तक कि एक अवलोकन उसे एक निश्चित अवस्था में "ढहा" नहीं देता।\n    *   (श्रोडिंगर की बिल्ली एक प्रसिद्ध विचार प्रयोग है जो इसे दर्शाता है, हालांकि यह क्वांटम दुनिया के लिए एक सादृश्य है, न कि मैक्रोस्कोपिक बिल्लियों का शाब्दिक विवरण)।\n\n6.  **उलझाव (Entanglement):**\n    *   जब दो या दो से अधिक क्वांटम कण "उलझ जाते हैं," तो वे इस तरह से जुड़ जाते हैं कि वे एक ही भाग्य साझा करते हैं, चाहे वे कितनी भी दूर क्यों न हों।\n    *   एक उलझे हुए कण के एक गुण को मापने से दूसरे के गुण पर तुरंत प्रभाव पड़ता है, भले ही वे प्रकाश-वर्ष दूर हों। अल्बर्ट आइंस्टीन ने इसे प्रसिद्ध रूप से "दूर से रहस्यमय क्रिया" (spooky action at a distance) कहा था।\n\n7.  **संभाव्यता, नियतिवाद नहीं:**\n    *   शास्त्रीय भौतिकी के विपरीत, जो अक्सर सटीक परिणामों की भविष्यवाणी कर सकती है, क्वांटम भौतिकी अक्सर संभावनाओं में काम करती है। यह आपको किसी कण को \u200b\u200bएक निश्चित अवस्था या स्थिति में खोजने की *संभावना* बताती है, न कि उसकी सटीक प्रक्षेपवक्र (trajectory)।\n\n**यह महत्वपूर्ण क्यों है?**\n\nक्वांटम भौतिकी केवल सैद्धांतिक विचित्रता नहीं है; यह अविश्वसनीय रूप से सटीक है और आधुनिक तकनीक और ब्रह्मांड की हमारी समझ का आधार बनती है:\n\n*   **लेज़र:** डीवीडी प्लेयर से लेकर फाइबर ऑप्टिक्स और चिकित्सा सर्जरी तक हर चीज़ में उपयोग किए जाते हैं।\n*   **ट्रांजिस्टर:** सभी आधुनिक इलेक्ट्रॉनिक्स (कंप्यूटर, स्मार्टफोन) के मूलभूत निर्माण खंड।\n*   **एमआरआई स्कैनर:** चिकित्सा इमेजिंग ज ...
